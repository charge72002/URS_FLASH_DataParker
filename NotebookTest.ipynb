# %% [markdown]
# Imports:

# %%
import yt
from yt.units import kpc

# %% [markdown]
# Particle Plot

# %%
ds = yt.load("IsolatedGalaxy/galaxy0030/galaxy0030")
particlePlot = yt.ParticlePlot(ds, 'particle_position_x', 'particle_position_y', 'particle_mass')
particlePlot.annotate_title("IsolatedGalaxy Particle Plot + Mass")
particlePlot.save("YT_Test_Plots/2DParticlePlot_B")
particlePlot.show()
# Out:
# yt : [INFO     ] 2021-03-16 11:37:59,409 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2021-03-16 11:37:59,409 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2021-03-16 11:37:59,413 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-03-16 11:37:59,413 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-03-16 11:37:59,413 Parameters: cosmological_simulation   = 0.0
# Parsing Hierarchy : 100%|██████████████████████████████████████████████████████████| 173/173 [00:00<00:00, 8652.28it/s]
# yt : [INFO     ] 2021-03-16 11:37:59,459 Gathering a field list (this may take a moment.)
# yt : [INFO     ] 2021-03-16 11:38:01,273 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-03-16 11:38:01,273 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-03-16 11:38:01,273 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-03-16 11:38:01,273 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-03-16 11:38:01,273 Splatting (('all', 'particle_mass')) onto a 800 by 800 mesh
# yt : [INFO     ] 2021-03-16 11:38:04,263 Saving plot YT_Test_Plots/2DParticlePlot_B_Particle_z_particle_mass.png
# D:\Anaconda\lib\site-packages\matplotlib\colors.py:1171: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# D:\Anaconda\lib\site-packages\matplotlib\colors.py:1171: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
